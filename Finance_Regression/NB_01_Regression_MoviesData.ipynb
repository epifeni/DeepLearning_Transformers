# %% [markdown]
# # PART 5: Regression Analysis

# %% [markdown]
# ## Correlation & Regression

# %% [markdown]
# ### Getting and Preparing the Data (Part 1)

# %% [markdown]
# Kaffel Movies Data: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset

# %%
import pandas as pd

# %%
movie = pd.read_csv("/Users/tanojudawattage/1_tanoj/0.00_Cloud_Computing_and_Streaming_Tech/BusinessandFinanceBootcamp_Files/Course_Materials_Part5/Video_Lectures_NBs/movies_metadata.csv", low_memory= False)

# %%
movie
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
pd.to_datetime(movie.release_date, errors = "coerce")
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45461          NaT
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45466, dtype: datetime64[ns]

# %%
movie = movie.set_index(pd.to_datetime(movie.release_date, errors = "coerce")).drop(columns = ["release_date"])

# %%
movie.sort_index(inplace = True)

# %%
movie
# Out:
#               adult belongs_to_collection budget  \
# release_date
# 1874-12-09    False                   NaN      0
# 1878-06-14    False                   NaN      0
# 1883-11-19    False                   NaN      0
# 1887-08-18    False                   NaN      0
# 1888-01-01    False                   NaN      0
# ...             ...                   ...    ...
# NaT           False                   NaN      0
# NaT           False                   NaN      0
# NaT           False                   NaN      0
# NaT           False                   NaN      0
# NaT           False                   NaN      0
#
#                                                          genres  \
# release_date
# 1874-12-09                  [{'id': 99, 'name': 'Documentary'}]
# 1878-06-14                  [{'id': 99, 'name': 'Documentary'}]
# 1883-11-19                  [{'id': 99, 'name': 'Documentary'}]
# 1887-08-18                  [{'id': 99, 'name': 'Documentary'}]
# 1888-01-01                  [{'id': 99, 'name': 'Documentary'}]
# ...                                                         ...
# NaT                                                          []
# NaT           [{'id': 9648, 'name': 'Mystery'}, {'id': 878, ...
# NaT                                                          []
# NaT           [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# NaT           [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                           homepage      id    imdb_id  \
# release_date
# 1874-12-09                                     NaN  315946  tt3155794
# 1878-06-14                                     NaN  194079  tt2221420
# 1883-11-19                                     NaN  426903  tt5459794
# 1887-08-18                                     NaN  159897  tt2075247
# 1888-01-01                                     NaN   96882  tt1758563
# ...                                            ...     ...        ...
# NaT                                            NaN  438910  tt0810384
# NaT                                            NaN  433711  tt3158690
# NaT                                            NaN  335251  tt1883368
# NaT                                            NaN  449131  tt0321264
# NaT           http://www.imdb.com/title/tt6209470/  439050  tt6209470
#
#              original_language  \
# release_date
# 1874-12-09                  xx
# 1878-06-14                  en
# 1883-11-19                  en
# 1887-08-18                  xx
# 1888-01-01                  xx
# ...                        ...
# NaT                         ru
# NaT                         en
# NaT                         en
# NaT                         ru
# NaT                         fa
#
#                                               original_title  \
# release_date
# 1874-12-09                                  Passage de Venus
# 1878-06-14                        Sallie Gardner at a Gallop
# 1883-11-19                                   Buffalo Running
# 1887-08-18                       Man Walking Around a Corner
# 1888-01-01                                  Accordion Player
# ...                                                      ...
# NaT                        Konstruktor krasnogo tsveta -1993
# NaT           All Superheroes Must Die 2: The Last Superhero
# NaT                           The Land Where the Blues Began
# NaT                                                    Aprel
# NaT                                                  رگ خواب
#
#                                                        overview  ...  \
# release_date                                                     ...
# 1874-12-09    Photo sequence of the rare transit of Venus ov...  ...
# 1878-06-14    Sallie Gardner at a Gallop was one of the earl...  ...
# 1883-11-19    Individual photographs of the running of a buf...  ...
# 1887-08-18    The last remaining production of Le Prince's L...  ...
# 1888-01-01    The last remaining film of Le Prince's LPCCP T...  ...
# ...                                                         ...  ...
# NaT           Engineering Red - 1993  Dir: Andrey I. Y. Petr...  ...
# NaT           In a no holds barred documentary, acclaimed jo...  ...
# NaT           An exploration of the musical and social origi...  ...
# NaT                                                         NaN  ...
# NaT                 Rising and falling between a man and woman.  ...
#
#                                            production_countries revenue  \
# release_date
# 1874-12-09             [{'iso_3166_1': 'FR', 'name': 'France'}]     0.0
# 1878-06-14    [{'iso_3166_1': 'US', 'name': 'United States o...     0.0
# 1883-11-19    [{'iso_3166_1': 'US', 'name': 'United States o...     0.0
# 1887-08-18    [{'iso_3166_1': 'US', 'name': 'United States o...     0.0
# 1888-01-01     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     0.0
# ...                                                         ...     ...
# NaT                                                          []     0.0
# NaT                                                          []     0.0
# NaT                                                          []     0.0
# NaT                    [{'iso_3166_1': 'RU', 'name': 'Russia'}]     0.0
# NaT                      [{'iso_3166_1': 'IR', 'name': 'Iran'}]     0.0
#
#              runtime                              spoken_languages    status  \
# release_date
# 1874-12-09       1.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 1878-06-14       1.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 1883-11-19       1.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 1887-08-18       1.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 1888-01-01       1.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# ...              ...                                           ...       ...
# NaT             76.0                                            []  Released
# NaT             74.0      [{'iso_639_1': 'en', 'name': 'English'}]  Released
# NaT              0.0                                            []  Released
# NaT              NaN                                            []  Released
# NaT             90.0        [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
#
#                                                  tagline  \
# release_date
# 1874-12-09                                           NaN
# 1878-06-14                                           NaN
# 1883-11-19                                           NaN
# 1887-08-18                                           NaN
# 1888-01-01                                           NaN
# ...                                                  ...
# NaT                                                  NaN
# NaT                                                  NaN
# NaT                                                  NaN
# NaT                                                  NaN
# NaT           Rising and falling between a man and woman
#
#                                                        title  video  \
# release_date
# 1874-12-09                                  Passage of Venus  False
# 1878-06-14                        Sallie Gardner at a Gallop  False
# 1883-11-19                                   Buffalo Running  False
# 1887-08-18                       Man Walking Around a Corner  False
# 1888-01-01                                  Accordion Player  False
# ...                                                      ...    ...
# NaT                                          Engineering Red  False
# NaT           All Superheroes Must Die 2: The Last Superhero  False
# NaT                           The Land Where the Blues Began  False
# NaT                                                    Aprel  False
# NaT                                                   Subdue  False
#
#              vote_average vote_count
# release_date
# 1874-12-09            6.0       19.0
# 1878-06-14            6.2       25.0
# 1883-11-19            5.4        7.0
# 1887-08-18            4.1       17.0
# 1888-01-01            4.4       18.0
# ...                   ...        ...
# NaT                   6.0        2.0
# NaT                   4.0        1.0
# NaT                   0.0        0.0
# NaT                   6.0        1.0
# NaT                   4.0        1.0
#
# [45466 rows x 23 columns]

# %%
df = movie.loc[:, ["title", "budget", "revenue"]].copy()

# %%
df
# Out:
#                                                        title budget  revenue
# release_date
# 1874-12-09                                  Passage of Venus      0      0.0
# 1878-06-14                        Sallie Gardner at a Gallop      0      0.0
# 1883-11-19                                   Buffalo Running      0      0.0
# 1887-08-18                       Man Walking Around a Corner      0      0.0
# 1888-01-01                                  Accordion Player      0      0.0
# ...                                                      ...    ...      ...
# NaT                                          Engineering Red      0      0.0
# NaT           All Superheroes Must Die 2: The Last Superhero      0      0.0
# NaT                           The Land Where the Blues Began      0      0.0
# NaT                                                    Aprel      0      0.0
# NaT                                                   Subdue      0      0.0
#
# [45466 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45466 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45466 non-null  object
#  2   revenue  45460 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.4+ MB

# %%
df.budget = pd.to_numeric(df.budget, errors = "coerce")

# %% [markdown]
# ### Getting and preparing the Data (Part 2)

# %%
df
# Out:
#                                                        title  budget  revenue
# release_date
# 1874-12-09                                  Passage of Venus     0.0      0.0
# 1878-06-14                        Sallie Gardner at a Gallop     0.0      0.0
# 1883-11-19                                   Buffalo Running     0.0      0.0
# 1887-08-18                       Man Walking Around a Corner     0.0      0.0
# 1888-01-01                                  Accordion Player     0.0      0.0
# ...                                                      ...     ...      ...
# NaT                                          Engineering Red     0.0      0.0
# NaT           All Superheroes Must Die 2: The Last Superhero     0.0      0.0
# NaT                           The Land Where the Blues Began     0.0      0.0
# NaT                                                    Aprel     0.0      0.0
# NaT                                                   Subdue     0.0      0.0
#
# [45466 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45466 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45463 non-null  float64
#  2   revenue  45460 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#              budget       revenue
# count  4.546300e+04  4.546000e+04
# mean   4.224579e+06  1.120935e+07
# std    1.742413e+07  6.433225e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    3.800000e+08  2.787965e+09

# %%
df.iloc[:, -2:]  = df.iloc[:, -2:] / 1000000

# %%
df
# Out:
#                                                        title  budget  revenue
# release_date
# 1874-12-09                                  Passage of Venus     0.0      0.0
# 1878-06-14                        Sallie Gardner at a Gallop     0.0      0.0
# 1883-11-19                                   Buffalo Running     0.0      0.0
# 1887-08-18                       Man Walking Around a Corner     0.0      0.0
# 1888-01-01                                  Accordion Player     0.0      0.0
# ...                                                      ...     ...      ...
# NaT                                          Engineering Red     0.0      0.0
# NaT           All Superheroes Must Die 2: The Last Superhero     0.0      0.0
# NaT                           The Land Where the Blues Began     0.0      0.0
# NaT                                                    Aprel     0.0      0.0
# NaT                                                   Subdue     0.0      0.0
#
# [45466 rows x 3 columns]

# %%
df.describe()
# Out:
#              budget       revenue
# count  45463.000000  45460.000000
# mean       4.224579     11.209349
# std       17.424133     64.332247
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max      380.000000   2787.965087

# %%
df.loc[df.title.isna()]
# Out:
#              title  budget  revenue
# release_date
# NaT            NaN     0.0      NaN
# NaT            NaN     NaN      NaN
# NaT            NaN     0.0      NaN
# NaT            NaN     NaN      NaN
# NaT            NaN     0.0      NaN
# NaT            NaN     NaN      NaN

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45460 entries, 1874-12-09 to NaT
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    45460 non-null  object
#  1   budget   45460 non-null  float64
#  2   revenue  45460 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 1.4+ MB

# %%
df.budget.value_counts()
# Out:
# budget
# 0.000000     36570
# 5.000000       286
# 10.000000      259
# 20.000000      243
# 2.000000       242
#              ...
# 5.005600         1
# 8.620000         1
# 0.762241         1
# 2.791874         1
# 0.566000         1
# Name: count, Length: 1223, dtype: int64

# %%
df.revenue.value_counts()
# Out:
# revenue
# 0.000000      38052
# 12.000000        20
# 11.000000        19
# 10.000000        19
# 2.000000         18
#               ...
# 66.913939         1
# 184.770205        1
# 24.527158         1
# 9.705840          1
# 4.219536          1
# Name: count, Length: 6863, dtype: int64

# %%
df = df.loc[(df.revenue > 0) & (df.budget > 0)]

# %%
df
# Out:
#                                      title     budget     revenue
# release_date
# 1915-02-08           The Birth of a Nation   0.100000   11.000000
# 1915-12-13                       The Cheat   0.017311    0.137365
# 1916-12-24    20,000 Leagues Under the Sea   0.200000    8.000000
# 1918-08-01                          Mickey   0.250000    8.000000
# 1921-01-21                         The Kid   0.250000    2.500000
# ...                                    ...        ...         ...
# 2017-07-26                   Atomic Blonde  30.000000   90.007945
# 2017-07-28                 The Emoji Movie  50.000000   66.913939
# 2017-08-03                  The Dark Tower  60.000000   71.000000
# 2017-08-03                      Wind River  11.000000  184.770205
# 2017-08-04                          Kidnap  21.000000   24.527158
#
# [5381 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5381 entries, 1915-02-08 to 2017-08-04
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    5381 non-null   object
#  1   budget   5381 non-null   float64
#  2   revenue  5381 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 168.2+ KB

# %%
df.describe()
# Out:
#             budget      revenue
# count  5381.000000  5381.000000
# mean     31.094796    90.318123
# std      40.162625   166.142264
# min       0.000001     0.000001
# 25%       5.037000     7.011317
# 50%      17.000000    29.918745
# 75%      40.000000    99.965753
# max     380.000000  2787.965087

# %%
df.sort_values("budget", ascending = False)
# Out:
#                                                     title      budget  \
# release_date
# 2011-05-14    Pirates of the Caribbean: On Stranger Tides  380.000000
# 2007-05-19       Pirates of the Caribbean: At World's End  300.000000
# 2015-04-22                        Avengers: Age of Ultron  280.000000
# 2006-06-28                               Superman Returns  270.000000
# 2010-11-24                                        Tangled  260.000000
# ...                                                   ...         ...
# 2015-12-04                                    The Letters    0.000001
# 2012-03-30                                 Aquí Entre Nos    0.000001
# 2003-05-05                                          Saamy    0.000001
# 2003-08-15                                      Tere Naam    0.000001
# 1955-03-09                                   East of Eden    0.000001
#
#                   revenue
# release_date
# 2011-05-14    1045.713802
# 2007-05-19     961.000000
# 2015-04-22    1405.403694
# 2006-06-28     391.081192
# 2010-11-24     591.794936
# ...                   ...
# 2015-12-04       0.000001
# 2012-03-30       2.755584
# 2003-05-05       0.000003
# 2003-08-15       0.000002
# 1955-03-09       0.000005
#
# [5381 rows x 3 columns]

# %%
df.sort_values("revenue", ascending = False)
# Out:
#                                      title      budget      revenue
# release_date
# 2009-12-10                          Avatar  237.000000  2787.965087
# 2015-12-15    Star Wars: The Force Awakens  245.000000  2068.223624
# 1997-11-18                         Titanic  200.000000  1845.034188
# 2012-04-25                    The Avengers  220.000000  1519.557910
# 2015-06-09                  Jurassic World  150.000000  1513.528810
# ...                                    ...         ...          ...
# 2003-08-15                       Tere Naam    0.000001     0.000002
# 2015-12-04                     The Letters    0.000001     0.000001
# 1996-10-16         The Wind in the Willows    0.000012     0.000001
# 1995-09-28                    Mute Witness    0.000002     0.000001
# 1925-08-26                 The Merry Widow    0.000592     0.000001
#
# [5381 rows x 3 columns]

# %%
df.to_csv("bud_vs_rev.csv")

# %% [markdown]
# ### How to calculate Covariance and Correlation

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("bud_vs_rev.csv", parse_dates = ["release_date"], index_col = "release_date")

# %%
df
# Out:
#                                      title     budget     revenue
# release_date
# 1915-02-08           The Birth of a Nation   0.100000   11.000000
# 1915-12-13                       The Cheat   0.017311    0.137365
# 1916-12-24    20,000 Leagues Under the Sea   0.200000    8.000000
# 1918-08-01                          Mickey   0.250000    8.000000
# 1921-01-21                         The Kid   0.250000    2.500000
# ...                                    ...        ...         ...
# 2017-07-26                   Atomic Blonde  30.000000   90.007945
# 2017-07-28                 The Emoji Movie  50.000000   66.913939
# 2017-08-03                  The Dark Tower  60.000000   71.000000
# 2017-08-03                      Wind River  11.000000  184.770205
# 2017-08-04                          Kidnap  21.000000   24.527158
#
# [5381 rows x 3 columns]

# %%
df = df.loc["2016"]

# %%
df
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 235 entries, 2016-01-01 to 2016-12-25
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    235 non-null    object
#  1   budget   235 non-null    float64
#  2   revenue  235 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 7.3+ KB

# %%
df.describe()
# Out:
#            budget      revenue
# count  235.000000   235.000000
# mean    40.461695   126.074160
# std     51.435816   215.314723
# min      0.000500     0.000050
# 25%      8.500000     5.889868
# 50%     20.000000    32.000000
# 75%     45.500000   142.200330
# max    250.000000  1153.304495

# %%
df.mean(numeric_only=True)
# Out:
# budget      40.461695
# revenue    126.074160
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# budget      2645.643127
# revenue    46360.429784
# dtype: float64

# %%
df.cov(numeric_only=True)
# Out:
#               budget       revenue
# budget   2645.643127   8861.380845
# revenue  8861.380845  46360.429784

# %%
df.budget.cov(df.revenue)
# Out:
# np.float64(8861.380845230346)

# %%
df.corr(numeric_only=True)
# Out:
#            budget   revenue
# budget   1.000000  0.800133
# revenue  0.800133  1.000000

# %%
df.budget.corr(df.revenue)
# Out:
# np.float64(0.8001327462030162)

# %%
df.budget.cov(df.revenue) / (df.budget.std() * df.revenue.std())
# Out:
# np.float64(0.8001327462030166)

# %%
np.cov(df.budget, df.revenue)
# Out:
# array([[ 2645.64312661,  8861.38084523],
#        [ 8861.38084523, 46360.42978363]])

# %%
np.corrcoef(df.budget, df.revenue)
# Out:
# array([[1.        , 0.80013275],
#        [0.80013275, 1.        ]])

# %% [markdown]
# ### Correlation and Scatterplots – visual Interpretation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bud_vs_rev.csv", parse_dates = ["release_date"], index_col = "release_date")

# %%
df = df.loc["2016"]

# %%
df
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %%
df.plot(kind = "scatter", x = "budget", y = "revenue", figsize = (15, 10), fontsize = 15)
plt.xlabel("Budget (in MUSD)", fontsize = 13)
plt.ylabel("Revenue (in MUSD)", fontsize = 13)
plt.show()

# %%
sns.set(font_scale=1.5)
sns.jointplot(data = df, x = "budget", y = "revenue", height = 8)
plt.show()

# %% [markdown]
# ### Creating a Confidence Interval for the Correlation Coefficient (Bootstrapping)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(precision=2, suppress= True)

# %%
df = pd.read_csv("bud_vs_rev.csv", parse_dates = ["release_date"], index_col = "release_date")

# %%
df = df.loc["2016"]

# %%
df
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %%
array = df.iloc[:, -2:].values
array
# Out:
# array([[  25.  ,    1.4 ],
#        [   9.9 ,    2.4 ],
#        [  10.  ,   40.06],
#        [   5.2 ,    9.2 ],
#        [  50.  ,   69.41],
#        [  18.  ,   17.06],
#        [  40.  ,  124.83],
#        [  38.  ,  109.91],
#        [  11.5 ,   94.07],
#        [  38.  ,  112.34],
#        [  10.  ,   64.19],
#        [   4.5 ,   32.  ],
#        [   3.5 ,    0.62],
#        [ 145.  ,  521.17],
#        [  80.  ,   52.1 ],
#        [   0.3 ,    2.1 ],
#        [  20.  ,   21.16],
#        [   0.  ,    0.  ],
#        [  13.5 ,    3.34],
#        [   0.3 ,    2.5 ],
#        [  10.  ,   18.73],
#        [  28.  ,   16.37],
#        [   0.33,    1.6 ],
#        [  22.  ,   63.65],
#        [  13.  ,    1.65],
#        [  50.  ,   55.97],
#        [  60.72,  553.81],
#        [  58.  ,  783.11],
#        [ 120.  ,  415.48],
#        [  20.  ,  183.94],
#        [   0.2 ,    5.5 ],
#        [  15.  ,   77.  ],
#        [ 175.  ,  745.6 ],
#        [  30.  ,   57.81],
#        [  21.5 ,    4.81],
#        [  65.  ,  143.7 ],
#        [  15.05,   16.18],
#        [   9.  ,    4.6 ],
#        [  12.  ,   37.59],
#        [  40.  ,   86.23],
#        [ 100.  ,   94.06],
#        [  60.  ,   69.93],
#        [  40.  ,  125.73],
#        [   9.9 ,  157.1 ],
#        [   3.8 ,    1.02],
#        [   0.76,    0.29],
#        [   8.  ,    8.81],
#        [  20.  ,   25.96],
#        [   0.7 ,    0.2 ],
#        [  60.  ,  238.47],
#        [   8.5 ,   15.86],
#        [  10.  ,   30.66],
#        [   5.  ,    6.7 ],
#        [  90.  ,  162.36],
#        [  35.  ,  211.95],
#        [   5.  ,   45.17],
#        [   1.5 ,    0.78],
#        [  40.  ,   37.28],
#        [  70.  ,  182.38],
#        [   5.  ,    2.39],
#        [  15.  ,   10.37],
#        [ 110.  ,  296.49],
#        [ 110.  ,  121.79],
#        [  25.  ,   29.2 ],
#        [   7.5 ,    9.1 ],
#        [  12.82,    6.1 ],
#        [  10.  ,    4.07],
#        [  45.  ,  173.19],
#        [   8.5 ,   19.99],
#        [   8.14,    1.86],
#        [  40.  ,  175.3 ],
#        [  43.  ,   46.65],
#        [   3.5 ,    4.1 ],
#        [   8.  ,    0.29],
#        [ 125.  ,  346.86],
#        [  75.  ,  220.02],
#        [  10.  ,    6.27],
#        [  44.  ,  155.16],
#        [  30.  ,    8.57],
#        [   6.  ,    1.31],
#        [  60.  ,  162.15],
#        [  10.3 ,    0.05],
#        [   9.  ,   81.71],
#        [  40.  ,   29.92],
#        [   0.45,    2.3 ],
#        [   4.  ,   65.05],
#        [   1.5 ,    2.  ],
#        [ 165.  ,  677.72],
#        [  12.16,    7.9 ],
#        [   8.  ,    0.08],
#        [   6.  ,    6.17],
#        [   9.  ,    9.  ],
#        [  22.5 ,   29.25],
#        [  47.  ,  203.39],
#        [  40.  ,   30.93],
#        [  17.  ,   42.49],
#        [  10.  ,   13.08],
#        [   9.  ,  276.92],
#        [ 180.  ,  809.34],
#        [   5.  ,    2.15],
#        [  85.  ,  119.52],
#        [   9.  ,   75.03],
#        [   9.  ,   18.8 ],
#        [  75.  ,  632.44],
#        [  25.  ,    3.89],
#        [  26.  ,   17.78],
#        [ 150.  ,  643.03],
#        [  25.  ,   23.96],
#        [   4.3 ,    3.38],
#        [  12.  ,  140.3 ],
#        [  13.  ,    3.5 ],
#        [  45.  ,  114.5 ],
#        [  14.  ,   13.82],
#        [  35.  ,   81.09],
#        [  30.  ,  445.44],
#        [   5.  ,    6.34],
#        [   9.  ,   13.96],
#        [  36.  ,   87.42],
#        [  25.  ,  230.7 ],
#        [  45.  ,   50.55],
#        [  30.  ,    2.35],
#        [ 200.  , 1056.06],
#        [ 150.  ,  331.96],
#        [  24.  ,   64.41],
#        [ 125.  ,   64.49],
#        [ 110.  ,  303.14],
#        [ 125.  ,  240.7 ],
#        [  20.  ,    7.23],
#        [  38.  ,  118.03],
#        [  46.  ,   23.74],
#        [  40.  ,  312.24],
#        [  50.  ,  102.21],
#        [  10.4 ,  310.  ],
#        [ 108.  ,   22.68],
#        [   7.  ,    5.82]])

# %%
array.shape
# Out:
# (235, 2)

# %%
np.corrcoef(array.T)[0, 1]
# Out:
# np.float64(0.8001327462030162)

# %%
size = array.shape[0]
size
# Out:
# 235

# %% [markdown]
# __one bootstrap sample__

# %%
np.random.seed(123)
indxs = np.random.randint(low = 0, high = size, size = size)

# %%
indxs
# Out:
# array([109, 126,  66, 220,  98, 230,  17,  83, 106, 123,  57, 214, 225,
#         96, 113, 126,  47,  73,  32, 174, 224, 111, 153,  83,  78, 164,
#         96, 208,  68,  49,  55, 195,   2,  84,  39,  66,  84,  47, 189,
#        176, 135, 105,  99, 124,  92, 180, 102,  97, 213, 118,  94, 155,
#         34, 225,  76, 168, 131, 106,  69,  64,  75, 162,  58, 138,  22,
#        205, 146, 228,  15, 155, 158, 180,  70, 109, 115, 154, 208, 134,
#         14, 103, 203, 182, 199, 129,  43, 186, 101, 183,  25, 178, 212,
#         56,  49,  12,  18, 209,   1,  51, 172, 117, 233,  48,  56, 219,
#        177,  86,   3,  67, 139, 149, 217, 103, 233,  98,   3, 139,   3,
#        222,   6,   9,  87,  14, 230, 211, 121, 198, 140, 182,  27,  38,
#        145, 189, 110,  74,  99, 116,  99, 193,  47,  16, 133, 104, 109,
#         86,  46,  15,  59,  40, 153,  45, 177,   0, 163, 157, 129, 211,
#         68, 158, 135,  93, 230,  60,  65, 116, 204,  67,  44,  51, 135,
#        230,  88, 198, 141, 156, 108,  63,  84, 164, 119, 224, 121, 168,
#        216, 116, 191,  58,  77,   8, 206, 134,  65, 222, 198,  40, 119,
#        202,  76, 204, 153, 234, 123, 135,  13, 172,   1, 169, 206, 184,
#        215,  63, 225,   3,  17,  88, 215, 197,  97,  50, 101, 130, 146,
#         46,  45, 185, 163,  18, 219, 174, 182,  73, 209,  62, 195, 139,
#        154])

# %%
array[indxs]
# Out:
# array([[ 180.  ,  356.74],
#        [  18.7 ,   74.  ],
#        [  20.  ,   55.03],
#        [  30.  ,    2.35],
#        [ 200.  , 1028.57],
#        [  40.  ,  312.24],
#        [   0.  ,    0.  ],
#        [ 178.  ,  543.93],
#        [   0.52,    1.01],
#        [   3.5 ,    3.77],
#        [   3.2 ,    4.27],
#        [  30.  ,  445.44],
#        [ 110.  ,  303.14],
#        [   3.5 ,    1.49],
#        [  33.  ,   77.07],
#        [  18.7 ,   74.  ],
#        [  15.  ,  108.29],
#        [  16.5 ,    0.02],
#        [  20.  ,   46.07],
#        [ 125.  ,  346.86],
#        [ 125.  ,   64.49],
#        [   5.  ,    5.88],
#        [  90.  ,  162.36],
#        [ 178.  ,  543.93],
#        [  73.  ,  349.78],
#        [   7.5 ,    9.1 ],
#        [   3.5 ,    1.49],
#        [   4.3 ,    3.38],
#        [  15.  ,   20.57],
#        [   4.  ,   13.62],
#        [  10.  ,    3.4 ],
#        [  17.  ,   42.49],
#        [  10.  ,   40.06],
#        [   2.  ,    0.34],
#        [  40.  ,   86.23],
#        [  35.  ,  211.95]])

# %%
np.corrcoef(array[indxs].T)[0, 1]
# Out:
# np.float64(0.7981448204332643)

# %% [markdown]
# __many bootstrap samples__

# %%
sims = 100000

# %%
np.random.seed(123)
indxs = np.random.randint(low = 0, high = size, size = size * sims).reshape(sims, size)

# %%
indxs.shape
# Out:
# (100000, 235)

# %%
indxs
# Out:
# array([[109, 126,  66, ..., 195, 139, 154],
#        [ 92, 203, 138, ..., 233, 219,  79],
#        [112, 106, 219, ..., 130, 149,  84],
#        ...,
#        [ 19, 223,   3, ..., 141, 119,  27],
#        [ 17, 169,  87, ..., 223, 193, 150],
#        [193, 165, 230, ..., 133, 110, 163]], shape=(100000, 235))

# %%
corr = []
for i in range(sims):
    corr.append(np.corrcoef(array[indxs[i]].T)[0, 1])

# %%
corr
# Out:
# [np.float64(0.7981448204332643),
#  np.float64(0.8191044990560746),
#  np.float64(0.8237491882953754),
#  np.float64(0.7714744355222746),
#  np.float64(0.7646349094333266),
#  np.float64(0.7458451512909035),
#  np.float64(0.7949066424345487),
#  np.float64(0.7774860985514475),
#  np.float64(0.7870927128777789),
#  np.float64(0.7624231378434181),
#  np.float64(0.8027592932895113),
#  np.float64(0.7317052227235344),
#  np.float64(0.7911832825191356),
#  np.float64(0.8599378654289733),
#  np.float64(0.8050415397815204),
#  np.float64(0.7693562131102888),
#  np.float64(0.7798866358760899),
#  np.float64(0.788317112918505),
#  np.float64(0.8110164433562934),
#  np.float64(0.7624187786892054),
#  np.float64(0.801319333373326),
#  np.float64(0.7756331548103326),
#  np.float64(0.8425669168496039),
#  np.float64(0.6932822250071159),
#  np.float64(0.7765961564288452),
#  np.float64(0.8075085913817472),
#  np.float64(0.8180393205661157),
#  np.float64(0.7800613634126948),
#  np.float64(0.8044447254360999),
#  np.float64(0.8327937148850691),
#  np.float64(0.8524531461210351),
#  np.float64(0.7554694647248859),
#  np.float64(0.8105441354428087),
#  np.float64(0.8067284358108171),
#  np.float64(0.7671660334129021),
#  np.float64(0.7649370036057856),
#  np.float64(0.7615598329527081),
#  np.float64(0.8472178392162452),
#  np.float64(0.7799020962947802),
#  np.float64(0.8293781277651946),
#  np.float64(0.8432238615808866),
#  np.float64(0.8548139299329944),
#  np.float64(0.7914571036945892),
#  np.float64(0.8169641744458059),
#  np.float64(0.83790670087962),
#  np.float64(0.8321587324483204),
#  np.float64(0.8284468319765358),
#  np.float64(0.784027947943902),
#  np.float64(0.7527590149392023),
#  np.float64(0.7875923996567153),
#  np.float64(0.8293354751973735),
#  np.float64(0.8032300581267505),
#  np.float64(0.7914229890946991),
#  np.float64(0.8221265084279415),
#  np.float64(0.7497904438087649),
#  np.float64(0.7898819864340988),
#  np.float64(0.8140754437451745),
#  np.float64(0.7815376515077261),
#  np.float64(0.85551057124022),
#  np.float64(0.803200943773294),
#  np.float64(0.8226585500391376),
#  np.float64(0.8779874369471622),
#  np.float64(0.858559631185871),
#  np.float64(0.7926746617626477),
#  np.float64(0.7933964063728753),
#  np.float64(0.7775823910205083),
#  np.float64(0.8342354548612175),
#  np.float64(0.845776036436857),
#  np.float64(0.7848541238193719),
#  np.float64(0.8600767981847254),
#  np.float64(0.7454510563535954),
#  np.float64(0.7664076599962217),
#  np.float64(0.806667791045596),
#  np.float64(0.8485990108527437),
#  np.float64(0.7956481046169938),
#  np.float64(0.7992458877098833),
#  ...]

# %%
plt.figure(figsize = (15, 10))
plt.hist(corr, bins = 500)
plt.show()

# %%
np.min(corr)
# Out:
# np.float64(0.5778957658085604)

# %% [markdown]
# __95% Confidence Interval Estimate__

# %%
np.percentile(corr, [2.5, 97.5])
# Out:
# array([0.72, 0.86])

# %% [markdown]
# ### Testing for Correlation (t-Test)

# %% [markdown]
# Calculate the __Correlation Coefficient__ (r) between __Movie Budgets__ and __Movie Revenues__ (for Movies released in 2016) and __test on a 5% significance level__, whether there is a linear relationship (H0: r == 0).

# %%
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv("bud_vs_rev.csv", parse_dates = ["release_date"], index_col = "release_date")

# %%
df = df.loc["2016"]

# %%
df
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %% [markdown]
# __H0: r == 0__ <br>
# __Ha: r != 0__

# %%
r, p_value = stats.pearsonr(df.budget, df.revenue)

# %%
r
# Out:
# np.float64(0.8001327462030164)

# %%
p_value
# Out:
# np.float64(1.2387431075240917e-53)

# %% [markdown]
# ### A simple Linear Regression Model with numpy & scipy & seaborn

# %% [markdown]
# Create a __simple Linear Regression Model__ with the __independent variable Movie Budget__ and one __dependent variable Movie Revenue__. <br>
# Visualize and interpret the __regression coefficients__.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
np.set_printoptions(precision=2, suppress= True)

# %%
df = pd.read_csv("bud_vs_rev.csv", parse_dates = ["release_date"], index_col = "release_date")

# %%
df = df.loc["2016"]

# %%
df
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %%
sns.set(font_scale=1.5)
y
# Out:
# array([   1.4 ,    2.4 ,   40.06,    9.2 ,   69.41,   17.06,  124.83,
#         109.91,   94.07,  112.34,   64.19,   32.  ,    0.62,  521.17,
#          52.1 ,    2.1 ,   21.16,    0.  ,    3.34,    2.5 ,   18.73,
#          16.37,    1.6 ,   63.65,    1.65,   55.97,  553.81,  783.11,
#           0.44, 1023.78,    3.62,    6.21,   46.07,    2.98,   12.64,
#          40.42,   24.8 ,   25.18,  150.68,   46.15,    0.03,  205.75,
#           0.  ,    5.9 ,   12.12,   23.08,  179.25,  108.29,    6.49,
#          13.62,    0.23,    0.28,   73.88,  873.26,   88.92,    3.4 ,
#          23.51,    4.27,    1.98,  164.6 ,  966.55,   78.64,    8.82,
#          14.71,   29.25,    3.22,   55.03,   27.31,   20.57,   14.4 ,
#           4.21, 1153.3 ,   48.42,    0.02,  108.76,   15.  ,   48.9 ,
#          43.76,  349.78,   93.28,  320.17,   10.9 ,   62.79,  543.93,
#           0.34,    2.34,  433.68,  299.37,   14.02,  245.62,    1.98,
#         183.35,  207.95,  334.9 ,    1.33,    4.82,    1.49,  216.97,
#        1028.57,   14.9 ,  875.46,  389.68,  408.58,    4.21,  119.1 ,
#           0.  ,    1.01,   25.04,  118.59,  356.74,   13.  ,    5.88,
#         102.  ,   77.07,  343.47,    9.42,   84.55,  140.71,   15.44,
#           1.39,  229.15,    0.1 ,    2.13,    3.77,  148.87,   58.5 ,
#          74.  ,   85.24,  415.48,  183.94,    5.5 ,   77.  ,  745.6 ,
#          57.81,    4.81,  143.7 ,   16.18,    4.6 ,   37.59,   86.23,
#          94.06,   69.93,  125.73,  157.1 ,    1.02,    0.29,    8.81,
#          25.96,    0.2 ,  238.47,   15.86,   30.66,    6.7 ,  162.36,
#         211.95,   45.17,    0.78,   37.28,  182.38,    2.39,   10.37,
#         296.49,  121.79,   29.2 ,    9.1 ,    6.1 ,    4.07,  173.19,
#          19.99,    1.86,  175.3 ,   46.65,    4.1 ,    0.29,  346.86,
#         220.02,    6.27,  155.16,    8.57,    1.31,  162.15,    0.05,
#          81.71,   29.92,    2.3 ,   65.05,    2.  ,  677.72,    7.9 ,
#           0.08,    6.17,    9.  ,   29.25,  203.39,   30.93,   42.49,
#          13.08,  276.92,  809.34,    2.15,  119.52,   75.03,   18.8 ,
#         632.44,    3.89,   17.78,  643.03,   23.96,    3.38,  140.3 ,
#           3.5 ,  114.5 ,   13.82,   81.09,  445.44,    6.34,   13.96,
#          87.42,  230.7 ,   50.55,    2.35, 1056.06,  331.96,   64.41,
#          64.49,  303.14,  240.7 ,    7.23,  118.03,   23.74,  312.24,
#         102.21,  310.  ,   22.68,    5.82])

# %%
reg = np.polyfit(x = x, y = y, deg = 1)
reg
# Out:
# array([ 3.35, -9.45])

# %%
np.polyfit(x = df.budget, y = df.revenue, deg = 1)
# Out:
# array([ 3.35, -9.45])

# %%
X = np.array([min(x), max(x)]) #creating x and y values for regression line

# %%
X
# Out:
# array([  0., 250.])

# %%
Y = np.polyval(reg, X)

# %%
Y
# Out:
# array([ -9.45, 827.91])

# %%
plt.figure(figsize = (12, 8))
plt.plot(X, Y)
plt.scatter(x = x, y = y)
plt.xlabel("Budget (in MUSD)")
plt.ylabel("Revenue (in MUSD)")
plt.show()

# %% [markdown]
# __Linear Regression with scipy__

# %%
df
# Out:
#                                                   title  budget     revenue
# release_date
# 2016-01-01                               Jane Got a Gun    25.0    1.397284
# 2016-01-07                               Friend Request     9.9    2.400000
# 2016-01-07                                   The Forest    10.0   40.055439
# 2016-01-07                                        Wazir     5.2    9.200000
# 2016-01-13    13 Hours: The Secret Soldiers of Benghazi    50.0   69.411370
# ...                                                 ...     ...         ...
# 2016-12-23             Resident Evil: The Final Chapter    40.0  312.242626
# 2016-12-23                              Railroad Tigers    50.0  102.205175
# 2016-12-23                                       Dangal    10.4  310.000000
# 2016-12-25                                Live by Night   108.0   22.678555
# 2016-12-25                           20th Century Women     7.0    5.816211
#
# [235 rows x 3 columns]

# %%
stats.linregress(x = df.budget, y = df.revenue)
# Out:
# LinregressResult(slope=np.float64(3.3494240988498905), intercept=np.float64(-9.449215053886661), rvalue=np.float64(0.8001327462030164), pvalue=np.float64(1.238743107523989e-53), stderr=np.float64(0.16449519793934378), intercept_stderr=np.float64(10.75090807524931))

# %% [markdown]
# ### How to interpret Regression Coefficients (Intercept and Slope)

# %%
stats.linregress(x = df.budget, y = df.revenue)
# Out:
# LinregressResult(slope=np.float64(3.3494240988498905), intercept=np.float64(-9.449215053886661), rvalue=np.float64(0.8001327462030164), pvalue=np.float64(1.238743107523989e-53), stderr=np.float64(0.16449519793934378), intercept_stderr=np.float64(10.75090807524931))

# %%
plt.figure(figsize = (12, 8))
plt.plot(X, Y)
plt.grid()
plt.scatter(x = x, y = y)
plt.xlabel("Budget (in MUSD)", fontsize = 15)
plt.ylabel("Revenue (in MUSD)", fontsize = 15)
plt.title("Linear Regression Model Revenue vs. Budget", fontsize = 15)
plt.show()

# %%
df.budget.cov(df.revenue) / df.budget.var()
# Out:
# np.float64(3.34942409884989)

# %% [markdown]
# ## Case Study (Part 1): The Market Model (Single Factor Model)

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[100], line 2
#       1 import pandas as pd
# ----> 2 import yfinance as yf
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
df = yf.download(["MSFT", "^SP500TR"], start = "2015-12-31", end = "2018-12-31")

# %%
df

# %%
df = df["Adj Close"]

# %%
df

# %%
ret = df.pct_change().dropna()

# %%
ret

# %%
ret.plot(x = "^SP500TR", y = "MSFT", figsize = (12, 8), kind = "scatter")
plt.grid()
plt.title("MSFT vs. SP500 (daily returns)", fontsize = 15)
plt.show()

# %%
r, p_value = stats.pearsonr(ret["^SP500TR"], ret.MSFT)

# %%
r

# %%
p_value

# %% [markdown]
# ## Case Study (Part 2): The Market Model (Single Factor Model)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
beta, intercept, rvalue, pvalue, stderr = stats.linregress(x = ret["^SP500TR"], y = ret.MSFT)

# %%
beta

# %%
intercept

# %%
rvalue

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = ret, x = "^SP500TR", y = "MSFT", height = 8, ci = None)
plt.show()
